# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\manideep\Downloads\App Analytics Report-06.05.2023.xlsx",  sheet_name=None)

# %%
# Access individual sheets by their names
sheet_names = df.keys()

# Example: Reading data from a specific sheet
# Replace 'Sheet1' with the name of the sheet you want to read
sheet_name = 'Event Report'
data_from_sheet = df[sheet_name]

# Now you can work with 'data_from_sheet', which is a pandas DataFrame
# For example, you can display the first few rows:

# %%
data_from_sheet
# Out:
#                         Event name  Event count  Total users  \
# 0                      screen_view       694729        23254
# 1             notification_receive       125146         1700
# 2                  user_engagement       124836        22699
# 3             notification_dismiss        70128         1369
# 4                    session_start        61163        23226
# ..                             ...          ...          ...
# 374  Promilo119_myProfile_mediator            1            1
# 375                  Promilo_feeds            1            1
# 376                          feeds            1            1
# 377            my_interests_screen            1            1
# 378                      (not set)            0        22269
#
#      Event count per user  Total revenue
# 0               30.865870              0
# 1              138.896800              0
# 2                5.622230              0
# 3              144.000000              0
# ...

# %%
# Access individual sheets by their names
sheet_names = df.keys()

# Example: Reading data from a specific sheet
# Replace 'Sheet1' with the name of the sheet you want to read
sheet_name = 'Traffic Aquisition'
df2 = df[sheet_name]

# Now you can work with 'data_from_sheet', which is a pandas DataFrame
# For example, you can display the first few rows:

# %%
# Access individual sheets by their names
sheet_names = df.keys()

# Example: Reading data from a specific sheet
# Replace 'Sheet1' with the name of the sheet you want to read
sheet_name = 'User Acquisition'
df3 = df[sheet_name]

# Now you can work with 'data_from_sheet', which is a pandas DataFrame
# For example, you can display the first few rows:

# %%
df3
# Out:
#   First user default channel group  New users  Engaged sessions  \
# 0                          Display       9957             12008
# 1                   Organic Search       7652             18141
# 2                      Paid Search       3025              4408
# 3                           Direct       1903              4975
# 4                       Unassigned        325              1619
# 5                   Organic Social         10                13
#
#    Engagement rate  Engaged sessions per user  Average engagement time  \
# 0         0.544457                   1.206107                 58.86209
# 1         0.813680                   2.367041                534.31280
# 2         0.474284                   1.458154                102.23780
# 3         0.318808                   2.261364               1128.88100
# 4         0.813159                   4.981538                798.34150
# 5         0.722222                   1.300000                145.30000
#
# ...

# %%
sheet_names = df.keys()

sheet_name = 'Demographics Report'
df4 = df[sheet_name]

# %%
df4.describe()
# Out:
#               Users     New users  Engaged sessions  Engagement rate  \
# count     47.000000     47.000000         47.000000        47.000000
# mean     500.148936    486.638298        890.340426         0.561662
# std     3357.099816   3285.103773       6049.238031         0.358970
# min        0.000000      0.000000          0.000000         0.000000
# 25%        1.000000      0.000000          1.000000         0.364286
# 50%        2.000000      1.000000          1.000000         0.533333
# 75%        7.000000      3.000000          6.000000         1.000000
# max    23024.000000  22528.000000      41479.000000         1.000000
#
#        Engaged sessions per user  Average engagement time   Event count  \
# count                  47.000000                47.000000  4.700000e+01
# mean                    0.835367                48.376626  2.805381e+04
# std                     0.568228                93.511799  1.913692e+05
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    47 non-null     object
#  1   Users                      47 non-null     int64
#  2   New users                  47 non-null     int64
#  3   Engaged sessions           47 non-null     int64
#  4   Engagement rate            47 non-null     float64
#  5   Engaged sessions per user  47 non-null     float64
#  6   Average engagement time    47 non-null     float64
#  7   Event count                47 non-null     int64
#  8   Conversions                47 non-null     int64
#  9   Total revenue              47 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 3.8+ KB

# %%
df4.columns
# Out:
# Index(['Country', 'Users', 'New users', 'Engaged sessions', 'Engagement rate',
#        'Engaged sessions per user', 'Average engagement time', 'Event count',
#        'Conversions', 'Total revenue'],
#       dtype='object')

# %%
df4.columns
# Out:
# Index(['Country', 'Users', 'New users', 'Engaged sessions', 'Engagement rate',
#        'Engaged sessions per user', 'Average engagement time', 'Event count',
#        'Conversions', 'Total revenue'],
#       dtype='object')

# %%
cont_cols = ['Users', 'New users', 'Engaged sessions', 'Engagement rate',
       'Engaged sessions per user', 'Average engagement time', 'Event count',
       'Conversions', 'Total revenue']

# %%
x = df4["Country"]
for i in cont_cols:
        plt.bar(x, df4[i])
        plt.xticks(fontsize = 7, rotation = 90)
        plt.yticks(fontsize = 7)
        plt.xlabel("Country", fontsize = 10)
        plt.ylabel(i,fontsize = 10)
        plt.show()

# %% [markdown]
# Insights:
#
# -->The "Engagement rate" is typically calculated as the percentage of engaged sessions out of total sessions for each country.  Since the numerator (engaged sessions) and denominator (total sessions) are both based on the number of sessions, the contribution of each country to the "Engagement rate" is more evenly distributed. Similarly, "Engaged Sessions per User" is calculated by dividing the total number of engaged sessions by the total number of users in each country.
# In contrast, the first set of metrics ("Engaged sessions', 'New Users', 'Engagement Sessions', and 'Users') are absolute counts, not ratios or percentages. The values for these metrics are directly based on the total count of sessions or users in each country, so countries with larger populations or higher levels of activity will naturally have higher counts. It happens the same with "Average Engagement Time".
# -->The even contribution of all countries to the engagement rate and engaged sessions per user plots could indicate that users from different countries are exhibiting similar engagement behaviors within their sessions, regardless of the total number of sessions or users in each country.
# -->In contrast, the other set of metrics (engaged sessions, new users, engagement sessions, users etc.,) are absolute counts, not ratios or percentages. The values for these metrics are directly based on the total count of sessions or users in each country, so countries with larger populations or higher levels of activity will naturally have higher counts.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df4' is your DataFrame with categorical variables

# Create subplots
fig, ax = plt.subplots(3, 3, figsize=(10, 6))
ax = ax.ravel()

# Plot each categorical feature using a box plot
for i, feature in enumerate(cont_cols):
    sns.boxplot(data=df4, x=feature, ax=ax[i])
    ax[i].set_xlabel('value')
    ax[i].set_ylabel(feature)

# Adjust the spacing between the subplots
plt.subplots_adjust(wspace=0.2)

# Display the plot
plt.suptitle("BOX PLOT CATEGORICAL VARIABLE")
plt.show()

# %% [markdown]
# Insights:
#
# -->From the above Box plot charts we can observe that in most of the attributes like "Users", "New Users", "Engaged Sessions"etc., there is only a single outlier. So from the previous charts we can come to a conclusion that this outlier is India.

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df4.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Insights:
#
# From the above chart we can identify many highly correlated columns like 'Users', 'New users', 'Engaged sessions', 'Event count', and 'Conversions'. It is better to drop these highly correlated columns by keeping only one representative column.
#
# It is better to work with either 'Engagement rate' or 'Engaged sessions per user' attribute, as they show a moderate correlation and might capture similar engagement aspects.
#
# 'Total revenue' column has constant values or missing data. It has no variation, you can consider dropping it from the dataset. Even in case of non profit applications the revenue remains zero.

# %%
import pandas as pd
# Assuming 'data' is your DataFrame containing the dataset
# Compute the correlation matrix
correlation_matrix = df4.corr()

# Create a mask to identify highly correlated columns
high_corr_mask = correlation_matrix.abs() >= 0.95

# Find duplicate columns (columns with high correlation)
duplicated_cols = set()
print("duplica", duplicated_cols)
print("high corr", high_corr_mask.columns)
for col in high_corr_mask.columns:
    if col not in duplicated_cols:
        duplicated_cols.update(set(high_corr_mask.index[high_corr_mask[col]]))

# Drop the duplicated columns
data_cleaned = df4.drop(columns=duplicated_cols)

# Drop 'Total revenue' column if it has NaN values
if 'Total revenue' in data_cleaned.columns and data_cleaned['Total revenue'].isnull().all():
    data_cleaned = data_cleaned.drop(columns='Total revenue')
# Out:
# duplica set()
# high corr Index(['Users', 'New users', 'Engaged sessions', 'Engagement rate',
#        'Engaged sessions per user', 'Average engagement time', 'Event count',
#        'Conversions', 'Total revenue'],
#       dtype='object')

# %%
# Access individual sheets by their names
sheet_names = df.keys()

# Example: Reading data from a specific sheet
# Replace 'Sheet1' with the name of the sheet you want to read
sheet_name = 'Pages & Screens Report'
df5 = df[sheet_name]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Page path and screen class  42 non-null     object
#  1   Views                       42 non-null     int64
#  2   Users                       42 non-null     int64
#  3   Views per user              42 non-null     float64
#  4   Average engagement time     42 non-null     float64
#  5   Event count                 42 non-null     int64
#  6   Conversions                 42 non-null     int64
#  7   Total revenue               42 non-null     int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 2.8+ KB

# %%
sns.heatmap(df5.corr())
# Out:
# <AxesSubplot:>

# %%
plt.bar(df5["Page path and screen class"], df5["Average engagement time"])
plt.xticks(fontsize = 8, rotation = 90)
plt.yticks(fontsize = 9)
plt.xlabel("Page path and screen class", fontsize = 10)
plt.ylabel("Average engagement time" ,fontsize = 10)
plt.show()

# %%
plt.scatter(df5["Event count"], df5["Conversions"])
plt.xticks(fontsize = 8, rotation = 90)
plt.yticks(fontsize = 9)
plt.xlabel("Event count", fontsize = 10)
plt.ylabel("Conversions" ,fontsize = 10)
plt.show()

# %%
sheet_names = df.keys()

sheet_name = 'Conversion Report'
df6 = df[sheet_name]
sheet_name = 'Event Report'
df7 = df[sheet_name]

# %%
plt.scatter(df6["Event name"], df6["Conversions"])
plt.xticks(fontsize = 8, rotation = 90)
plt.yticks(fontsize = 9)
plt.xlabel("Event name", fontsize = 10)
plt.ylabel("Conversions" ,fontsize = 10)
plt.show()

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Event name            378 non-null    object
#  1   Event count           379 non-null    int64
#  2   Total users           379 non-null    int64
#  3   Event count per user  379 non-null    float64
#  4   Total revenue         379 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 14.9+ KB

# %% [markdown]
# Insights:
#
# We can observe that there's no much impact of event count on conversions. We can see that notification receive event has more number of conversions.We can see that average engagement time is more for  "check out" page because it is a critical stage in the conversion funnel, and users' behavior on this page can significantly impact the conversion rate and revenue generation for e-commerce websites and applications. Optimizing the "check out" process, ensuring a smooth user experience, and addressing potential pain points can help increase the likelihood of successful checkouts and conversions. Also, conversions are mostly observed in the event 'notifications receive'. The notifications received by the users are grabbing users attention to click on it and thus increasing the number of conversions. So it is important to send attractive and interesting notifications to the users which helps in increasing the users count ultimately.
